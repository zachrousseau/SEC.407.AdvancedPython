# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. Read the data from the CSV file into a DataFrame and display the first five rows.

# %%
ramen_data = pd.read_csv('ramen-ratings.csv')
ramen_data.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %% [markdown]
# 2. Create a histogram for the Stars column using the number of bins necessary to display the ratings for
# each quarter of a star.

# %%
ramen_data.plot.hist(y='Stars', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 3. Create a KDE plot for the Stars column.

# %%
sns.kdeplot(ramen_data['Stars'], shade=True)
# Out:
# C:\Users\TacoZ\AppData\Local\Temp\ipykernel_33556\3713480150.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ramen_data['Stars'], shade=True)
# <Axes: xlabel='Stars', ylabel='Density'>

# %% [markdown]
# 4. Create a bar plot that shows the average number of stars by ramen style. Hint: You’ll need to group
# the data before you plot it.

# %%
(ramen_data.groupby('Style')['Stars'].mean()).plot.bar(title='Average Number of Stars by Ramen Style')
# Out:
# <Axes: xlabel='Style'>

# %% [markdown]
# 5. Create a bar plot that shows the total number of reviews for each ramen type.

# %%
(ramen_data.groupby('Style')['Stars'].count()).plot.bar(title='Total Number of Review by Ramen Type')
# Out:
# <Axes: title={'center': 'Total Number of Review by Ramen Type'}, xlabel='Style'>

# %% [markdown]
# 6. Create a bar plot that shows the highest score given to each ramen type.

# %%
(ramen_data.groupby('Style')['Stars'].max()).plot.bar(title='Highest Score by each ramen type')
# Out:
# <Axes: title={'center': 'Highest Score by each ramen type'}, xlabel='Style'>
