# %% [markdown]
# 1. Read the data from the CSV file into a DataFrame.

# %%
import pandas as pd
avocado_data = pd.read_csv('avocado.csv')

# %% [markdown]
# 2. Display type, memory consumption, and null count information using the info() method

# %%
avocado_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# 3. Display the number of unique values in each column

# %%
avocado_data.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# 4. Display all the rows of data that JupyterLab displays by default

# %%
avocado_data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# 5. Display the first and last five rows of data and the first and last four columns of data.

# %%
avocado_data.iloc[[0,1,2,3,4,-5,-4,-3,-2,-1], [0,-3,-2,-1]]
# Out:
#        Unnamed: 0          type  year            region
# 0               0  conventional  2015            Albany
# 1               1  conventional  2015            Albany
# 2               2  conventional  2015            Albany
# 3               3  conventional  2015            Albany
# 4               4  conventional  2015            Albany
# 18244           7       organic  2018  WestTexNewMexico
# 18245           8       organic  2018  WestTexNewMexico
# 18246           9       organic  2018  WestTexNewMexico
# 18247          10       organic  2018  WestTexNewMexico
# 18248          11       organic  2018  WestTexNewMexico

# %% [markdown]
# 6. Choose any three columns, access them with bracket notation, and display the first five rows of this
# data.

# %%
avocado_data[['type', 'region', 'year']].head(5)
# Out:
#            type  region  year
# 0  conventional  Albany  2015
# 1  conventional  Albany  2015
# 2  conventional  Albany  2015
# 3  conventional  Albany  2015
# 4  conventional  Albany  2015

# %% [markdown]
# 7. Select one column and access it with dot notation

# %%
avocado_data.region
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %% [markdown]
# 8. Multiply the Total Volume and AveragePrice columns, and store the result in a new column called
# EstimatedRevenue. Then, display the first five rows of this data to confirm that the column was added
# and has the correct values.

# %%
avocado_data['EstimatedRevenue'] = \
    avocado_data["Total Volume"] * avocado_data["AveragePrice"]


avocado_data.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  EstimatedRevenue
# 0  2015  Albany        85434.7046
# ...

# %% [markdown]
# 9. Create a DataFrame that’s grouped by region and type and that includes the average price for the
# grouped columns. Then, reset the index and display the first five rows.

# %%
avocado_data_region_type = avocado_data.set_index(
    ['region', 'type'])
avocado_data_region_type.reset_index(inplace=True)
avocado_data_region_type.head(5)
# Out:
#    region          type  Unnamed: 0        Date  AveragePrice  Total Volume  \
# 0  Albany  conventional           0  2015-12-27          1.33      64236.62
# 1  Albany  conventional           1  2015-12-20          1.35      54876.98
# 2  Albany  conventional           2  2015-12-13          0.93     118220.22
# 3  Albany  conventional           3  2015-12-06          1.08      78992.15
# 4  Albany  conventional           4  2015-11-29          1.28      51039.60
#
#       4046       4225    4770  Total Bags  Small Bags  Large Bags  \
# 0  1036.74   54454.85   48.16     8696.87     8603.62       93.25
# 1   674.28   44638.81   58.33     9505.56     9408.07       97.49
# 2   794.70  109149.67  130.50     8145.35     8042.21      103.14
# 3  1132.00   71976.41   72.58     5811.16     5677.40      133.76
# 4   941.48   43838.39   75.78     6183.95     5986.26      197.69
#
#    XLarge Bags  year  EstimatedRevenue
# 0          0.0  2015        85434.7046
# ...

# %% [markdown]
# 10. Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by
# year.

# %%
avocado_data.groupby('year') \
    .agg('mean', 'median', 'std').plot.bar()
# Out:
# <Axes: xlabel='year'>
