# %% [markdown]
# # Assignment.07 - Program 03

# %%
# https://www.kaggle.com/residentmario/ramen-ratings
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %% [markdown]
# 1. Download the CSV file at this link and read the data into a DataFrame:

# %%
# 1
thanksgiving_data = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/thanksgiving-2015/thanksgiving-2015-poll-data.csv")
thanksgiving_data.head(5)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %% [markdown]
# 2. Download the Stata file at this link and read the data into a DataFrame:
# http://www.stata-press.com/data/r8/cancer.dta

# %%
cancer_data = pd.read_stata("http://www.stata-press.com/data/r8/cancer.dta")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cancer_data = pd.read_stata("http://www.stata-press.com/data/r8/cancer.dta")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\stata.py:2109, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2106     return reader
#    2108 with reader:
# -> 2109     return reader.read()
#
# ...

# %% [markdown]
# 3. Download the CSV file at this link and load the data into a DataFrame. You’ll need to create a Kaggle
# account if you do not already have one.
# https://www.kaggle.com/kaggle/sf-salaries

# %%
sf_salary_data = pd.read_csv('Salaries.csv')
sf_salary_data.head(5)
# Out:
# C:\Users\TacoZ\AppData\Local\Temp\ipykernel_20572\3389349073.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_salary_data = pd.read_csv('Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %% [markdown]
# 4. Search Kaggle for something that you are interested in to see if there is any data for that interest. If there
# is, download that dataset and load it into a DataFrame. If not, just download one of the trending datasets
# in the trending section as shown below:

# %%
air_data = pd.read_csv('AirQuality Dataset.csv')
air_data.head(5)
# Out:
#    Rank       City   Country   2023    Jan    Feb    Mar    Apr    May   Jun  \
# 0     1  Begusarai     India  118.9   31.2  235.3  156.8    113  109.3    99
# 1     2   Guwahati     India  105.4  220.2  168.1  129.2  112.2   69.5  51.3
# 2     3      Delhi     India  102.1  171.8  114.3   77.4     71   67.4  42.9
# 3     4  Mullanpur     India  100.4  106.3  123.7   78.1   56.6   53.4  53.9
# 4     5     Lahore  Pakistan   99.5  143.2  117.3   73.8   52.9   52.4  46.4
#
#     Jul   Aug   Sep    Oct    Nov    Dec
# 0  63.8  61.8  71.5   61.8  210.5    285
# 1  46.6  60.2  76.7   76.4  126.9    128
# 2  35.3  34.8  39.7  106.3  255.1    210
# 3  63.2  59.7  59.6  110.4    253  201.4
# 4  39.8  42.2  53.8  125.9    251  197.5
