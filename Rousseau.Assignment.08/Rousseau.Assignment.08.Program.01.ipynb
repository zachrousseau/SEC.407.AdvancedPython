# %% [markdown]
# # Assignment 8 - Program

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %% [markdown]
# 1. Read the data from the CSV file into a DataFrame and display the data to get a count of the number of
# rows

# %%
# 1
ramen_data = pd.read_csv('ramen-ratings.csv')
ramen_data.shape[0]
# Out:
# 2577

# %% [markdown]
# 2. Rename the Stars column to Rating.

# %%
ramen_data = ramen_data.rename(columns={"Stars": "Rating"})

# %% [markdown]
# 3. Convert the Style column to the category type

# %%
ramen_data = ramen_data.rename(columns={"Style": "Category"})

# %% [markdown]
# 4. Drop the country column.

# %%
ramen_data = ramen_data.drop(columns=['Country'])

# %% [markdown]
# 5. Check that the changes were applied to the DataFrame.

# %%
ramen_data
# Out:
#                Brand                                            Variety  \
# 0          New Touch                          T's Restaurant Tantanmen
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2             Nissin                      Cup Noodles Chicken Vegetable
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor
# 4     Ching's Secret                                    Singapore Curry
# ...              ...                                                ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2573         Wai Wai                     Oriental Style Instant Noodles
# 2574         Wai Wai                                     Tom Yum Shrimp
# 2575         Wai Wai                               Tom Yum Chili Flavor
# 2576        Westbrae                                         Miso Ramen
#
#      Category  Rating
# 0         Cup    3.75
# 1        Pack    1.00
# 2         Cup    2.25
# ...

# %% [markdown]
# 6. Rename the Brand column to Company and the Variety column to Product

# %%
ramen_data = ramen_data.rename(columns={"Brand": "Company", "Variety": "Product"})
ramen_data.head(5)
# Out:
#           Company                                            Product Category  \
# 0       New Touch                          T's Restaurant Tantanmen       Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...     Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable      Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor     Pack
# 4  Ching's Secret                                    Singapore Curry     Pack
#
#    Rating
# 0    3.75
# 1    1.00
# 2    2.25
# 3    2.75
# 4    3.75

# %% [markdown]
# 7. Use the duplicated() method to display all rows with duplicate Company/Product combinations.

# %%
ramen_data[ramen_data.duplicated(keep='first', subset=('Company', 'Product'))]
# Out:
#               Company                                            Product  \
# 307    Sichuan Baijia              Chongqing Noodles Burning Dry Noodles
# 366             Paldo                                      Bul Jjamppong
# 697             Myojo                            Chicken Abalone Flavour
# 707            Nissin                    Cup Noodles Minced Pork Flavour
# 819            Nissin                      Cup Noodles Moo Manao Flavour
# 843       Master Kong                        Tomato Sauce Instant Noodle
# 858             Mamee                               Chef Lontong Flavour
# 896      Wugudaochang  Sour Bamboo Shoot & Beef If Hot Pot Flavor Noo...
# 897      Wugudaochang              Sea Tangle & Sparerins Flavor Noodles
# 997             Emart             Dare You! Habanero Ramen (New Edition)
# 1021   Ching's Secret                         Hot Garlic Instant Noodles
# 1077          MyKuali                    Penang Red Tom Yum Goong Noodle
# ...

# %% [markdown]
# 8. Drop all rows with duplicate Company/Product combinations except for the first row in each set. Then,
# display the data to get a count of the number of rows, and compare that with the original number of
# rows to see how many were dropped

# %%
ramen_data = ramen_data.drop_duplicates(keep='first', subset=('Company', 'Product'))
ramen_data.shape[0]
ramen_data
# Out:
#              Company                                            Product  \
# 0          New Touch                          T's Restaurant Tantanmen
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2             Nissin                      Cup Noodles Chicken Vegetable
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor
# 4     Ching's Secret                                    Singapore Curry
# ...              ...                                                ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2573         Wai Wai                     Oriental Style Instant Noodles
# 2574         Wai Wai                                     Tom Yum Shrimp
# 2575         Wai Wai                               Tom Yum Chili Flavor
# 2576        Westbrae                                         Miso Ramen
#
#      Category  Rating
# 0         Cup    3.75
# 1        Pack    1.00
# 2         Cup    2.25
# ...

# %% [markdown]
# 9. Drop any rows that have missing values

# %%
ramen_data.dropna(inplace=True)
# Out:
#              Company                                            Product  \
# 0          New Touch                          T's Restaurant Tantanmen
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2             Nissin                      Cup Noodles Chicken Vegetable
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor
# 4     Ching's Secret                                    Singapore Curry
# ...              ...                                                ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2573         Wai Wai                     Oriental Style Instant Noodles
# 2574         Wai Wai                                     Tom Yum Shrimp
# 2575         Wai Wai                               Tom Yum Chili Flavor
# 2576        Westbrae                                         Miso Ramen
#
#      Category  Rating
# 0         Cup    3.75
# 1        Pack    1.00
# 2         Cup    2.25
# ...

# %% [markdown]
# 10. Check again to make sure that all of your changes were applied.

# %%
ramen_data
# Out:
#              Company                                            Product  \
# 0          New Touch                          T's Restaurant Tantanmen
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2             Nissin                      Cup Noodles Chicken Vegetable
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor
# 4     Ching's Secret                                    Singapore Curry
# ...              ...                                                ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2573         Wai Wai                     Oriental Style Instant Noodles
# 2574         Wai Wai                                     Tom Yum Shrimp
# 2575         Wai Wai                               Tom Yum Chili Flavor
# 2576        Westbrae                                         Miso Ramen
#
#      Category  Rating
# 0         Cup    3.75
# 1        Pack    1.00
# 2         Cup    2.25
# ...
