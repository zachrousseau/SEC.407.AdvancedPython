# %% [markdown]
# # Assignment 9 - Program 1

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. Read the data from the CSV file into a DataFrame and display the first five rows

# %%
ramen_data = pd.read_csv('ramen-ratings.csv')
ramen_data.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %% [markdown]
# 2. Group the data and get the average of the groups to produce a DataFrame that looks like this:

# %%
ramen_data.groupby([
'Country', 'Brand', 'Style'
]).min()
# Out:
#                                                                         Variety  \
# Country   Brand        Style
# Australia Fantastic    Cup                               Noodle Chicken Flavour
#           Maggi        Pack   Fusian Special Edition Ow... Ow... Spicy Cow M...
#           Singa-Me     Cup                         Instant Noodles Beef Flavour
#           Suimin       Cup                 Noodle With Oriental Chicken Flavour
#           Trident      Pack                      2 Minute Laksa Flavour Noodles
# ...                                                                         ...
# Vietnam   Vifon        Pack                    Asian Style Instant Noodles Beef
#           Vina Acecook Bowl                          Bestcook Hot & Sour Shrimp
#                        Cup                           Hao Hao Sate Onion Flavour
#                        Pack                                     Daily Beef Ball
#                        Tray                          Kingcook Tomato Sauce Pork
#
#                               Stars
# Country   Brand        Style
# Australia Fantastic    Cup     1.00
#           Maggi        Pack    5.00
#           Singa-Me     Cup     2.00
#           Suimin       Cup     2.25
#           Trident      Pack    2.00
# ...                             ...
# Vietnam   Vifon        Pack    0.50
#           Vina Acecook Bowl    3.00
#                        Cup     2.50
#                        Pack    2.75
#                        Tray    3.50
#
# [578 rows x 2 columns]

# %% [markdown]
# 3. Group the data in the same way, but this time get both the average and the count.

# %%
ramen_group = ramen_data.groupby(['Country','Brand', 'Style']).agg({'Stars': ['mean', 'count']}) 
ramen_group
# Out:
#                                  Stars
#                                   mean count
# Country   Brand        Style
# Australia Fantastic    Cup    3.041667     6
#           Maggi        Pack   5.000000     1
#           Singa-Me     Cup    2.833333     3
#           Suimin       Cup    3.287500     8
#           Trident      Pack   2.750000     4
# ...                                ...   ...
# Vietnam   Vifon        Pack   2.877273    22
#           Vina Acecook Bowl   3.812500     4
#                        Cup    2.500000     1
#                        Pack   3.535714    28
#                        Tray   3.500000     1
#
# [578 rows x 2 columns]

# %% [markdown]
# 4. Create a pivot table that shows the average stars by ramen style for each country

# %%
ramen_data.pivot_table(index='Country', columns='Stars', values='Stars', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 ramen_data.pivot_table(index='Country', columns='Stars', values='Stars', aggfunc='mean')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:9496, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9479 @Substitution("")
#    9480 @Appender(_shared_docs["pivot_table"])
#    9481 def pivot_table(
#    (...)
#    9492     sort: bool = True,
#    9493 ) -> DataFrame:
#    9494     from pandas.core.reshape.pivot import pivot_table
# -> 9496     return pivot_table(
#    9497         self,
#    9498         values=values,
#    9499         index=index,
#    9500         columns=columns,
#    9501         aggfunc=aggfunc,
#    9502         fill_value=fill_value,
#    9503         margins=margins,
#    9504         dropna=dropna,
#    9505         margins_name=margins_name,
#    9506         observed=observed,
#    9507         sort=sort,
#    9508     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\pivot.py:172, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     169     values = list(values)
#     171 observed_bool = False if observed is lib.no_default else observed
# --> 172 grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:9170, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9167 if level is None and by is None:
#    9168     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9170 return DataFrameGroupBy(
#    9171     obj=self,
#    9172     keys=by,
#    9173     axis=axis,
#    9174     level=level,
#    9175     as_index=as_index,
#    9176     sort=sort,
#    9177     group_keys=group_keys,
#    9178     observed=observed,
#    9179     dropna=dropna,
#    9180 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\grouper.py:1038, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1034     in_axis, name, gpr = True, gpr, obj[gpr]
#    1035     if gpr.ndim != 1:
#    1036         # non-unique columns; raise here to get the name in the
#    1037         # exception message
# -> 1038         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#    1039     exclusions.add(name)
#    1040 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Stars' not 1-dimensional
